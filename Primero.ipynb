# %% [markdown]
# <a href="https://colab.research.google.com/github/alonsoposadilla-prog/Colaboraci-n-con-Colab/blob/main/Primero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #HOLA MUNDO

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
dia = 'lunes'
print(f'Hoy es {dia}')
# Out:
# Hoy es lunes
